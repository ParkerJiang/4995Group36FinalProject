# %%
from LGBMR_new import *
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31788324 entries, 0 to 31788323
# Data columns (total 5 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   customer_id       uint64
#  1   article_id        int32
#  2   price             float32
#  3   sales_channel_id  int8
#  4   week              int8
# dtypes: float32(1), int32(1), int8(2), uint64(1)
# memory usage: 545.7 MB
# @1.979s taken for {load}
# @9.414s taken for {getLastP}
# @2.103s taken for {getBestS}
# @17.436s taken for {concatAll}
# @30.933s taken for {preproc}
# @76.935s taken for {__init__}
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.848850
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.153099
# [LightGBM] [Debug] init for col-wise cost 0.136590 seconds, init for row-wise cost 0.152343 seconds
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.236223 seconds.
# ...

# %%
lgbmr01 = LGBMR()
lgbmr01.LGBMRT()
lgbmr01.LGBMRP()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31788324 entries, 0 to 31788323
# Data columns (total 5 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   customer_id       uint64
#  1   article_id        int32
#  2   price             float32
#  3   sales_channel_id  int8
#  4   week              int8
# dtypes: float32(1), int32(1), int8(2), uint64(1)
# memory usage: 545.7 MB
# @2.071s taken for {load}
# @9.543s taken for {getLastP}
# @2.012s taken for {getBestS}
# @17.341s taken for {concatAll}
# @30.968s taken for {preproc}
# @77.523s taken for {__init__}
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.848850
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.153099
# [LightGBM] [Debug] init for col-wise cost 0.133009 seconds, init for row-wise cost 0.158856 seconds
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.245802 seconds.
# ...

# %%
import lightgbm
lightgbm.plot_importance(lgbmr01.ranker, height = 0.7, max_num_features=10)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %% [markdown]
# The Mean Average Precision is 0.0208 (1,358/2,843)
#  on Kaggle Testing dataset.
